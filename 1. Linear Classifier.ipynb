# %% [markdown]
# # Create Linear Classifier
# **Steps**
#
# 1) Import Libraries
#
# 2) Prepare and Process the data
#
# 3) Define Variables
#
# 4) Define Functions to Calculate Loss and Accuracy
#
# 5) Define Linear Classifier Function
#
# 6) Plot the Data
#
# 7) Plot Resulting Images

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
print('x_train:', x_train.shape)
print('x_test:', x_test.shape)

# For CIFAR10
K = len(np.unique(y_train)) # Number of Classes; 10
Ntr = x_train.shape[0]  # Number of training samples; 50,000 
Nte = x_test.shape[0]   # Number of test samples; 10,000
Din = 3072 # CIFAR10

# Normalize pixel values
x_train, x_test = x_train / 255.0, x_test / 255.0
mean_image = np.mean(x_train, axis=0)   # Mean of the Image pixels 
x_train = x_train - mean_image
x_test = x_test - mean_image

# Convert 1-dimentional array class arrays to 10-dimentional class matrices 
y_train = tf.keras.utils.to_categorical(y_train, num_classes=K)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=K)

#Reshape and format
x_train = np.reshape(x_train,(Ntr,Din))
x_test = np.reshape(x_test,(Nte,Din))
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
# Out:
# x_train: (50000, 32, 32, 3)
# x_test: (10000, 32, 32, 3)

# %%
std=1e-6
w1 = std*np.random.randn(Din, K)
b1 = np.zeros(K)

#define variables 
batch_size = Ntr # Take all training data at onece; batch geadient decsent 
iterations = 300
lr = 0.01
lr_decay= 0.99
reg = 5e-6
loss_history = []
train_acc_history = []
val_acc_history = []

# %%
#Define a function to calculate the loss
def calc_loss(y, y_pred, w1, w2 = 0):
    batch_size=y_pred.shape[0]
    loss = 1./batch_size*np.square(y_pred - y).sum() + reg*(np.sum(w2*w2) + np.sum(w1*w1))
    return loss

# %%
#Define function to calculate the accuracy
def accuracy(y_pred,y):
    batch_size=y_pred.shape[0]
    K=y_pred.shape[1]
    acc=1-(1/(batch_size*K))*(np.abs(np.argmax(y,axis=1)-np.argmax(y_pred,axis=1))).sum() #Take max value in y and y_pred and take absolte value of the differece 
    return acc

# %%
#linear classifier
def classifier(x_train,y_train,x_test,y_test,K,Din,lr,lr_decay,reg):
    Ntr = x_train.shape[0]
    Nte = x_test.shape[0]

    loss_history = []
    train_acc_history = []
    val_acc_history = []
    seed = 0
    rng = np.random.default_rng(seed=seed)

    std=1e-5
    w1 = std*np.random.randn(Din, K) #create hypothesis function
    b1 = np.zeros(K)

    for t in range(iterations):
        indices = np.arange(Ntr)
        rng.shuffle(indices)
        x=x_train[indices]
        y=y_train[indices]

        #forward pass
        y_pred=x.dot(w1)+b1
        y_pred_test=x_test.dot(w1)+b1

        #Calculate training and validation losses
        train_loss=calc_loss(y_pred,y,w1)
        test_loss=calc_loss(y_pred_test,y_test,w1)
        loss_history.append(train_loss)
        
        #Calculate training and validation accuracies
        train_acc=accuracy(y_pred,y)
        train_acc_history.append(train_acc)
        test_acc=accuracy(y_pred_test,y_test)
        val_acc_history.append(test_acc)

        if t%10 == 0:
            print('Epoch %3d/%d:==> Train Loss= %f | Test Loss= %f | Train Accuracy= %f | Test Accuracy= %f' % (t,iterations,train_loss,test_loss,train_acc,test_acc))

        # Backward pass
        dy_pred=(1./batch_size)*2.0*(y_pred-y)
        dw1=x.T.dot(dy_pred)+reg*w1
        db1=dy_pred.sum(axis=0)
        w1-=lr*dw1
        b1-=lr*db1
        lr*=lr_decay
    return w1,b1,loss_history,train_acc_history,val_acc_history

# %%
w1_1,b1_1,loss_history_1,train_acc_history_1,val_acc_history_1=classifier(x_train, y_train, x_test, y_test, K, Din, lr, lr_decay, reg)
# Out:
# Epoch   0/300:==> Train Loss= 0.999993 | Test Loss= 0.999994 | Train Accuracy= 0.665148 | Test Accuracy= 0.663190
# Epoch  10/300:==> Train Loss= 0.893990 | Test Loss= 0.893448 | Train Accuracy= 0.752040 | Test Accuracy= 0.754420
# Epoch  20/300:==> Train Loss= 0.863946 | Test Loss= 0.863642 | Train Accuracy= 0.759132 | Test Accuracy= 0.762220
# Epoch  30/300:==> Train Loss= 0.845986 | Test Loss= 0.845834 | Train Accuracy= 0.761876 | Test Accuracy= 0.767600
# Epoch  40/300:==> Train Loss= 0.834140 | Test Loss= 0.834107 | Train Accuracy= 0.764180 | Test Accuracy= 0.769270
# Epoch  50/300:==> Train Loss= 0.825931 | Test Loss= 0.826001 | Train Accuracy= 0.765916 | Test Accuracy= 0.770700
# Epoch  60/300:==> Train Loss= 0.820036 | Test Loss= 0.820200 | Train Accuracy= 0.767234 | Test Accuracy= 0.771180
# Epoch  70/300:==> Train Loss= 0.815680 | Test Loss= 0.815928 | Train Accuracy= 0.767820 | Test Accuracy= 0.771520
# Epoch  80/300:==> Train Loss= 0.812378 | Test Loss= 0.812705 | Train Accuracy= 0.768680 | Test Accuracy= 0.771520
# Epoch  90/300:==> Train Loss= 0.809822 | Test Loss= 0.810220 | Train Accuracy= 0.769076 | Test Accuracy= 0.772280
# Epoch 100/300:==> Train Loss= 0.807806 | Test Loss= 0.808269 | Train Accuracy= 0.769508 | Test Accuracy= 0.772590
# Epoch 110/300:==> Train Loss= 0.806189 | Test Loss= 0.806712 | Train Accuracy= 0.770122 | Test Accuracy= 0.772870
# Epoch 120/300:==> Train Loss= 0.804874 | Test Loss= 0.805451 | Train Accuracy= 0.770510 | Test Accuracy= 0.772780
# Epoch 130/300:==> Train Loss= 0.803791 | Test Loss= 0.804417 | Train Accuracy= 0.770830 | Test Accuracy= 0.773030
# Epoch 140/300:==> Train Loss= 0.802889 | Test Loss= 0.803560 | Train Accuracy= 0.771136 | Test Accuracy= 0.773140
# Epoch 150/300:==> Train Loss= 0.802131 | Test Loss= 0.802842 | Train Accuracy= 0.771110 | Test Accuracy= 0.773220
# Epoch 160/300:==> Train Loss= 0.801489 | Test Loss= 0.802237 | Train Accuracy= 0.771498 | Test Accuracy= 0.773410
# Epoch 170/300:==> Train Loss= 0.800940 | Test Loss= 0.801721 | Train Accuracy= 0.771566 | Test Accuracy= 0.773420
# Epoch 180/300:==> Train Loss= 0.800469 | Test Loss= 0.801280 | Train Accuracy= 0.771590 | Test Accuracy= 0.773500
# Epoch 190/300:==> Train Loss= 0.800061 | Test Loss= 0.800899 | Train Accuracy= 0.771688 | Test Accuracy= 0.773430
# Epoch 200/300:==> Train Loss= 0.799707 | Test Loss= 0.800570 | Train Accuracy= 0.771872 | Test Accuracy= 0.773400
# Epoch 210/300:==> Train Loss= 0.799398 | Test Loss= 0.800284 | Train Accuracy= 0.771982 | Test Accuracy= 0.773580
# Epoch 220/300:==> Train Loss= 0.799127 | Test Loss= 0.800033 | Train Accuracy= 0.772120 | Test Accuracy= 0.773420
# Epoch 230/300:==> Train Loss= 0.798890 | Test Loss= 0.799814 | Train Accuracy= 0.772314 | Test Accuracy= 0.773440
# Epoch 240/300:==> Train Loss= 0.798680 | Test Loss= 0.799621 | Train Accuracy= 0.772396 | Test Accuracy= 0.773510
# Epoch 250/300:==> Train Loss= 0.798495 | Test Loss= 0.799450 | Train Accuracy= 0.772404 | Test Accuracy= 0.773650
# Epoch 260/300:==> Train Loss= 0.798331 | Test Loss= 0.799300 | Train Accuracy= 0.772554 | Test Accuracy= 0.773600
# Epoch 270/300:==> Train Loss= 0.798185 | Test Loss= 0.799166 | Train Accuracy= 0.772560 | Test Accuracy= 0.773340
# Epoch 280/300:==> Train Loss= 0.798055 | Test Loss= 0.799048 | Train Accuracy= 0.772578 | Test Accuracy= 0.773360
# Epoch 290/300:==> Train Loss= 0.797940 | Test Loss= 0.798942 | Train Accuracy= 0.772686 | Test Accuracy= 0.773570

# %%
fig, axes  = plt.subplots(1,4, sharex='all', sharey='all', figsize=(30,6))
items = {"Loss":loss_history_1, "Training Accuracy":train_acc_history_1,"Validation Accuracy": val_acc_history_1}

graph = 1
for key in items.keys():
    plt.subplot(1,3,graph);plt.plot(items[key], color='#0000ff', linewidth=4)
    plt.title(key)
    graph+=1

# %%
import cv2 as cv
images=[]
for i in range(w1_1.shape[1]):
    #images.append(np.reshape(w1[:,i]*255,(32,32,3))+np.reshape(mean_image,(32,32,3)))
    temp=np.reshape(w1_1[:,i]*255,(32,32,3))
    temp=cv.normalize(temp, None, 0, 255, cv.NORM_MINMAX, cv.CV_8U)
    images.append(temp)
lst = [['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer'],['Dog','Frog','Horse','Ship','Truck']]
fig,ax=plt.subplots(2,5,figsize=(30,10))
for i in range(2):
    for j in range(5):
        ax[i,j].set_title(lst[i][j])
        ax[i,j].imshow(images[i*5+j],vmin=0,vmax=255)
plt.show()
